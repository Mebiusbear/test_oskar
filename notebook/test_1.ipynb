# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import astropy.io.fits as fits

# %%
file_dir = "../origin_fits_data"

# %%
file_list = os.listdir(file_dir)

# %%
file_a = os.path.join(file_dir,file_list[0])
fits_a = fits.open(file_a)

# %%
file_b = "../test_screen_60s.fits"
fits_b = fits.open(file_b)

# %%
fits_b[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -64 / array data type
# NAXIS   =                    4 / number of array dimensions
# NAXIS1  =                 2000
# NAXIS2  =                 2000
# NAXIS3  =                   60
# NAXIS4  =                    1
# WCSAXES =                    4 / Number of coordinate axes
# CRPIX1  =               1001.0 / Pixel coordinate of reference point
# CRPIX2  =               1001.0 / Pixel coordinate of reference point
# CRPIX3  =                 31.0 / Pixel coordinate of reference point
# CRPIX4  =                  1.0 / Pixel coordinate of reference point
# CDELT1  =                100.0 / Coordinate increment at reference point
# CDELT2  =                100.0 / Coordinate increment at reference point
# CDELT3  =                 60.0 / Coordinate increment at reference point
# CDELT4  =                  1.0 / [Hz] Coordinate increment at reference point
# ...

# %%
im_list = fits_b[0].data[0]
plt.imshow(im_list[2],cmap="gray")
plt.colorbar()

# %% [markdown]
# # part 1 确定观察位置
